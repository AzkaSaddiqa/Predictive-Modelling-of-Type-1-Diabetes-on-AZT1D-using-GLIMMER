# %% [markdown]
# #### Glimmer using transformer (6 features-trying paper accuracy)

# %%
import sys, tensorflow as tf
print(sys.executable)
print(tf.config.list_physical_devices("GPU"))
# Out:
# D:\CondaEnvironment\azka_tf_gpu_env\python.exe
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.23.5

# %%
#pip install -r requirements.txt

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
#################################Training#################################
# !python mainPersonalized_transformer.py
# Out:
# === Training patient Subject 1 ===
# Saved predictions for patient Subject 1 at ./glimmer_transformer_results/Subject 1\errors\predictions.csv
# Saved model for patient Subject 1 at ./glimmer_transformer_results/Subject 1\model
#
#
# --------------------- Patient ID: Subject 1 ---------------------
# Overall Error Metrics:
# Root Mean Squared Error (RMSE): 38.71
# Mean Squared Error (MSE): 1498.31
# Mean Absolute Error (MAE): 33.70
# Mean Absolute Percentage Error (MAPE): 0.22%
#
# Normal Region Error Metrics:
# Root Mean Squared Error (RMSE): 33.92
# Mean Squared Error (MSE): 1150.38
# Mean Absolute Error (MAE): 29.84
# Mean Absolute Percentage Error (MAPE): 0.21%
#
# dysglycemic Region Error Metrics:
# Root Mean Squared Error (RMSE): 60.51
# Mean Squared Error (MSE): 3661.71
# Mean Absolute Error (MAE): 57.69
# Mean Absolute Percentage Error (MAPE): 0.29%
#
# Hyperglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 60.82
# Mean Squared Error (MSE): 3698.66
# Mean Absolute Error (MAE): 58.11
# Mean Absolute Percentage Error (MAPE): 0.29%
#
# Hypoglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 32.08
# Mean Squared Error (MSE): 1029.09
# Mean Absolute Error (MAE): 27.22
# Mean Absolute Percentage Error (MAPE): 0.41%
#
#
# Clark Error Zone Distribution:
# Zone A: 323.00% (STD: 0.00%)
# Zone B: 1761.00% (STD: 0.00%)
# Zone C: 0.00% (STD: 0.00%)
# Zone D: 2.00% (STD: 0.00%)
# Zone E: 0.00% (STD: 0.00%)
#
# === Training patient Subject 10 ===
# Saved predictions for patient Subject 10 at ./glimmer_transformer_results/Subject 10\errors\predictions.csv
# Saved model for patient Subject 10 at ./glimmer_transformer_results/Subject 10\model
#
#
# --------------------- Patient ID: Subject 10 ---------------------
# Overall Error Metrics:
# Root Mean Squared Error (RMSE): 31.21
# Mean Squared Error (MSE): 974.31
# Mean Absolute Error (MAE): 23.37
# Mean Absolute Percentage Error (MAPE): 0.17%
#
# Normal Region Error Metrics:
# Root Mean Squared Error (RMSE): 23.84
# Mean Squared Error (MSE): 568.47
# Mean Absolute Error (MAE): 18.87
# Mean Absolute Percentage Error (MAPE): 0.15%
#
# dysglycemic Region Error Metrics:
# Root Mean Squared Error (RMSE): 64.76
# Mean Squared Error (MSE): 4194.35
# Mean Absolute Error (MAE): 59.04
# Mean Absolute Percentage Error (MAPE): 0.35%
#
# Hyperglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 67.73
# Mean Squared Error (MSE): 4587.96
# Mean Absolute Error (MAE): 62.50
# Mean Absolute Percentage Error (MAPE): 0.29%
#
# Hypoglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 42.81
# Mean Squared Error (MSE): 1832.70
# Mean Absolute Error (MAE): 38.28
# Mean Absolute Percentage Error (MAPE): 0.70%
#
#
# Clark Error Zone Distribution:
# Zone A: 1614.00% (STD: 0.00%)
# Zone B: 673.00% (STD: 0.00%)
# Zone C: 0.00% (STD: 0.00%)
# Zone D: 27.00% (STD: 0.00%)
# Zone E: 0.00% (STD: 0.00%)
#
# === Training patient Subject 11 ===
# Saved predictions for patient Subject 11 at ./glimmer_transformer_results/Subject 11\errors\predictions.csv
# Saved model for patient Subject 11 at ./glimmer_transformer_results/Subject 11\model
#
#
# --------------------- Patient ID: Subject 11 ---------------------
# Overall Error Metrics:
# Root Mean Squared Error (RMSE): 37.26
# Mean Squared Error (MSE): 1388.02
# Mean Absolute Error (MAE): 29.83
# Mean Absolute Percentage Error (MAPE): 0.18%
#
# Normal Region Error Metrics:
# Root Mean Squared Error (RMSE): 25.80
# Mean Squared Error (MSE): 665.81
# Mean Absolute Error (MAE): 21.50
# Mean Absolute Percentage Error (MAPE): 0.16%
#
# dysglycemic Region Error Metrics:
# Root Mean Squared Error (RMSE): 61.78
# Mean Squared Error (MSE): 3816.31
# Mean Absolute Error (MAE): 57.86
# Mean Absolute Percentage Error (MAPE): 0.27%
#
# Hyperglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 62.15
# Mean Squared Error (MSE): 3862.16
# Mean Absolute Error (MAE): 58.38
# Mean Absolute Percentage Error (MAPE): 0.27%
#
# Hypoglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 24.90
# Mean Squared Error (MSE): 619.99
# Mean Absolute Error (MAE): 22.13
# Mean Absolute Percentage Error (MAPE): 0.33%
#
#
# Clark Error Zone Distribution:
# Zone A: 1061.00% (STD: 0.00%)
# Zone B: 1338.00% (STD: 0.00%)
# Zone C: 0.00% (STD: 0.00%)
# Zone D: 69.00% (STD: 0.00%)
# Zone E: 0.00% (STD: 0.00%)
#
# === Training patient Subject 12 ===
# Saved predictions for patient Subject 12 at ./glimmer_transformer_results/Subject 12\errors\predictions.csv
# Saved model for patient Subject 12 at ./glimmer_transformer_results/Subject 12\model
#
#
# --------------------- Patient ID: Subject 12 ---------------------
# Overall Error Metrics:
# Root Mean Squared Error (RMSE): 32.09
# Mean Squared Error (MSE): 1029.77
# Mean Absolute Error (MAE): 26.36
# Mean Absolute Percentage Error (MAPE): 0.19%
#
# Normal Region Error Metrics:
# Root Mean Squared Error (RMSE): 28.04
# Mean Squared Error (MSE): 786.14
# Mean Absolute Error (MAE): 23.56
# Mean Absolute Percentage Error (MAPE): 0.18%
#
# dysglycemic Region Error Metrics:
# Root Mean Squared Error (RMSE): 53.57
# Mean Squared Error (MSE): 2869.90
# Mean Absolute Error (MAE): 47.49
# Mean Absolute Percentage Error (MAPE): 0.26%
#
# Hyperglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 58.46
# Mean Squared Error (MSE): 3417.64
# Mean Absolute Error (MAE): 54.83
# Mean Absolute Percentage Error (MAPE): 0.27%
#
# Hypoglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 16.20
# Mean Squared Error (MSE): 262.54
# Mean Absolute Error (MAE): 12.51
# Mean Absolute Percentage Error (MAPE): 0.21%
#
#
# Clark Error Zone Distribution:
# Zone A: 1005.00% (STD: 0.00%)
# Zone B: 1408.00% (STD: 0.00%)
# Zone C: 0.00% (STD: 0.00%)
# Zone D: 1.00% (STD: 0.00%)
# Zone E: 0.00% (STD: 0.00%)
#
# === Training patient Subject 13 ===
# Saved predictions for patient Subject 13 at ./glimmer_transformer_results/Subject 13\errors\predictions.csv
# Saved model for patient Subject 13 at ./glimmer_transformer_results/Subject 13\model
#
#
# --------------------- Patient ID: Subject 13 ---------------------
# Overall Error Metrics:
# Root Mean Squared Error (RMSE): 25.90
# Mean Squared Error (MSE): 670.87
# Mean Absolute Error (MAE): 20.33
# Mean Absolute Percentage Error (MAPE): 0.13%
#
# Normal Region Error Metrics:
# Root Mean Squared Error (RMSE): 22.41
# Mean Squared Error (MSE): 502.21
# Mean Absolute Error (MAE): 17.86
# Mean Absolute Percentage Error (MAPE): 0.12%
#
# dysglycemic Region Error Metrics:
# Root Mean Squared Error (RMSE): 49.94
# Mean Squared Error (MSE): 2494.49
# Mean Absolute Error (MAE): 47.05
# Mean Absolute Percentage Error (MAPE): 0.24%
#
# Hyperglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 50.13
# Mean Squared Error (MSE): 2512.74
# Mean Absolute Error (MAE): 47.30
# Mean Absolute Percentage Error (MAPE): 0.24%
#
# Hypoglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 24.79
# Mean Squared Error (MSE): 614.52
# Mean Absolute Error (MAE): 21.32
# Mean Absolute Percentage Error (MAPE): 0.33%
#
#
# Clark Error Zone Distribution:
# Zone A: 2093.00% (STD: 0.00%)
# Zone B: 362.00% (STD: 0.00%)
# Zone C: 0.00% (STD: 0.00%)
# Zone D: 2.00% (STD: 0.00%)
# Zone E: 0.00% (STD: 0.00%)
#
# === Training patient Subject 14 ===
# Saved predictions for patient Subject 14 at ./glimmer_transformer_results/Subject 14\errors\predictions.csv
# Saved model for patient Subject 14 at ./glimmer_transformer_results/Subject 14\model
#
#
# --------------------- Patient ID: Subject 14 ---------------------
# Overall Error Metrics:
# Root Mean Squared Error (RMSE): 34.43
# Mean Squared Error (MSE): 1185.08
# Mean Absolute Error (MAE): 27.54
# Mean Absolute Percentage Error (MAPE): 0.21%
#
# Normal Region Error Metrics:
# Root Mean Squared Error (RMSE): 32.45
# Mean Squared Error (MSE): 1053.05
# Mean Absolute Error (MAE): 26.65
# Mean Absolute Percentage Error (MAPE): 0.21%
#
# dysglycemic Region Error Metrics:
# Root Mean Squared Error (RMSE): 53.18
# Mean Squared Error (MSE): 2828.03
# Mean Absolute Error (MAE): 38.56
# Mean Absolute Percentage Error (MAPE): 0.29%
#
# Hyperglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 83.38
# Mean Squared Error (MSE): 6952.84
# Mean Absolute Error (MAE): 79.16
# Mean Absolute Percentage Error (MAPE): 0.40%
#
# Hypoglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 15.62
# Mean Squared Error (MSE): 243.95
# Mean Absolute Error (MAE): 13.13
# Mean Absolute Percentage Error (MAPE): 0.22%
#
#
# Clark Error Zone Distribution:
# Zone A: 1303.00% (STD: 0.00%)
# Zone B: 1162.00% (STD: 0.00%)
# Zone C: 0.00% (STD: 0.00%)
# Zone D: 13.00% (STD: 0.00%)
# Zone E: 0.00% (STD: 0.00%)
#
# === Training patient Subject 15 ===
# Saved predictions for patient Subject 15 at ./glimmer_transformer_results/Subject 15\errors\predictions.csv
# Saved model for patient Subject 15 at ./glimmer_transformer_results/Subject 15\model
#
#
# --------------------- Patient ID: Subject 15 ---------------------
# Overall Error Metrics:
# Root Mean Squared Error (RMSE): 33.04
# Mean Squared Error (MSE): 1091.32
# Mean Absolute Error (MAE): 22.37
# Mean Absolute Percentage Error (MAPE): 0.16%
#
# Normal Region Error Metrics:
# Root Mean Squared Error (RMSE): 22.03
# Mean Squared Error (MSE): 485.25
# Mean Absolute Error (MAE): 16.00
# Mean Absolute Percentage Error (MAPE): 0.13%
#
# dysglycemic Region Error Metrics:
# Root Mean Squared Error (RMSE): 64.95
# Mean Squared Error (MSE): 4218.56
# Mean Absolute Error (MAE): 55.22
# Mean Absolute Percentage Error (MAPE): 0.33%
#
# Hyperglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 78.34
# Mean Squared Error (MSE): 6136.75
# Mean Absolute Error (MAE): 74.09
# Mean Absolute Percentage Error (MAPE): 0.32%
#
# Hypoglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 24.40
# Mean Squared Error (MSE): 595.33
# Mean Absolute Error (MAE): 19.59
# Mean Absolute Percentage Error (MAPE): 0.36%
#
#
# Clark Error Zone Distribution:
# Zone A: 2037.00% (STD: 0.00%)
# Zone B: 954.00% (STD: 0.00%)
# Zone C: 0.00% (STD: 0.00%)
# Zone D: 52.00% (STD: 0.00%)
# Zone E: 0.00% (STD: 0.00%)
#
# === Training patient Subject 16 ===
# Saved predictions for patient Subject 16 at ./glimmer_transformer_results/Subject 16\errors\predictions.csv
# Saved model for patient Subject 16 at ./glimmer_transformer_results/Subject 16\model
#
#
# --------------------- Patient ID: Subject 16 ---------------------
# Overall Error Metrics:
# Root Mean Squared Error (RMSE): 31.90
# Mean Squared Error (MSE): 1017.37
# Mean Absolute Error (MAE): 24.96
# Mean Absolute Percentage Error (MAPE): 0.15%
#
# Normal Region Error Metrics:
# Root Mean Squared Error (RMSE): 21.75
# Mean Squared Error (MSE): 473.14
# Mean Absolute Error (MAE): 17.65
# Mean Absolute Percentage Error (MAPE): 0.13%
#
# dysglycemic Region Error Metrics:
# Root Mean Squared Error (RMSE): 56.02
# Mean Squared Error (MSE): 3137.70
# Mean Absolute Error (MAE): 53.44
# Mean Absolute Percentage Error (MAPE): 0.26%
#
# Hyperglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 56.02
# Mean Squared Error (MSE): 3137.70
# Mean Absolute Error (MAE): 53.44
# Mean Absolute Percentage Error (MAPE): 0.26%
#
# Hypoglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): nan
# Mean Squared Error (MSE): nan
# Mean Absolute Error (MAE): nan
# Mean Absolute Percentage Error (MAPE): nan%
#
#
# Clark Error Zone Distribution:
# Zone A: 1561.00% (STD: 0.00%)
# Zone B: 786.00% (STD: 0.00%)
# Zone C: 0.00% (STD: 0.00%)
# Zone D: 8.00% (STD: 0.00%)
# Zone E: 0.00% (STD: 0.00%)
#
# === Training patient Subject 17 ===
# Saved predictions for patient Subject 17 at ./glimmer_transformer_results/Subject 17\errors\predictions.csv
# Saved model for patient Subject 17 at ./glimmer_transformer_results/Subject 17\model
#
#
# --------------------- Patient ID: Subject 17 ---------------------
# Overall Error Metrics:
# Root Mean Squared Error (RMSE): 56.84
# Mean Squared Error (MSE): 3230.45
# Mean Absolute Error (MAE): 48.08
# Mean Absolute Percentage Error (MAPE): 0.27%
#
# Normal Region Error Metrics:
# Root Mean Squared Error (RMSE): 37.62
# Mean Squared Error (MSE): 1414.93
# Mean Absolute Error (MAE): 33.34
# Mean Absolute Percentage Error (MAPE): 0.24%
#
# dysglycemic Region Error Metrics:
# Root Mean Squared Error (RMSE): 80.13
# Mean Squared Error (MSE): 6421.02
# Mean Absolute Error (MAE): 73.97
# Mean Absolute Percentage Error (MAPE): 0.32%
#
# Hyperglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 80.97
# Mean Squared Error (MSE): 6555.68
# Mean Absolute Error (MAE): 75.33
# Mean Absolute Percentage Error (MAPE): 0.32%
#
# Hypoglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 14.22
# Mean Squared Error (MSE): 202.19
# Mean Absolute Error (MAE): 11.43
# Mean Absolute Percentage Error (MAPE): 0.20%
#
#
# Clark Error Zone Distribution:
# Zone A: 199.00% (STD: 0.00%)
# Zone B: 2161.00% (STD: 0.00%)
# Zone C: 0.00% (STD: 0.00%)
# Zone D: 112.00% (STD: 0.00%)
# Zone E: 0.00% (STD: 0.00%)
#
# === Training patient Subject 18 ===
# Saved predictions for patient Subject 18 at ./glimmer_transformer_results/Subject 18\errors\predictions.csv
# Saved model for patient Subject 18 at ./glimmer_transformer_results/Subject 18\model
#
#
# --------------------- Patient ID: Subject 18 ---------------------
# Overall Error Metrics:
# Root Mean Squared Error (RMSE): 42.86
# Mean Squared Error (MSE): 1837.30
# Mean Absolute Error (MAE): 30.97
# Mean Absolute Percentage Error (MAPE): 0.18%
#
# Normal Region Error Metrics:
# Root Mean Squared Error (RMSE): 23.45
# Mean Squared Error (MSE): 549.82
# Mean Absolute Error (MAE): 18.46
# Mean Absolute Percentage Error (MAPE): 0.14%
#
# dysglycemic Region Error Metrics:
# Root Mean Squared Error (RMSE): 76.78
# Mean Squared Error (MSE): 5895.53
# Mean Absolute Error (MAE): 70.42
# Mean Absolute Percentage Error (MAPE): 0.30%
#
# Hyperglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 77.38
# Mean Squared Error (MSE): 5987.78
# Mean Absolute Error (MAE): 71.29
# Mean Absolute Percentage Error (MAPE): 0.30%
#
# Hypoglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 21.29
# Mean Squared Error (MSE): 453.22
# Mean Absolute Error (MAE): 19.38
# Mean Absolute Percentage Error (MAPE): 0.30%
#
#
# Clark Error Zone Distribution:
# Zone A: 1075.00% (STD: 0.00%)
# Zone B: 862.00% (STD: 0.00%)
# Zone C: 0.00% (STD: 0.00%)
# Zone D: 56.00% (STD: 0.00%)
# Zone E: 0.00% (STD: 0.00%)
#
# === Training patient Subject 19 ===
# Saved predictions for patient Subject 19 at ./glimmer_transformer_results/Subject 19\errors\predictions.csv
# Saved model for patient Subject 19 at ./glimmer_transformer_results/Subject 19\model
#
#
# --------------------- Patient ID: Subject 19 ---------------------
# Overall Error Metrics:
# Root Mean Squared Error (RMSE): 30.20
# Mean Squared Error (MSE): 912.29
# Mean Absolute Error (MAE): 23.68
# Mean Absolute Percentage Error (MAPE): 0.16%
#
# Normal Region Error Metrics:
# Root Mean Squared Error (RMSE): 24.85
# Mean Squared Error (MSE): 617.63
# Mean Absolute Error (MAE): 20.15
# Mean Absolute Percentage Error (MAPE): 0.15%
#
# dysglycemic Region Error Metrics:
# Root Mean Squared Error (RMSE): 57.45
# Mean Squared Error (MSE): 3300.47
# Mean Absolute Error (MAE): 52.31
# Mean Absolute Percentage Error (MAPE): 0.27%
#
# Hyperglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 60.05
# Mean Squared Error (MSE): 3605.76
# Mean Absolute Error (MAE): 55.86
# Mean Absolute Percentage Error (MAPE): 0.26%
#
# Hypoglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 26.26
# Mean Squared Error (MSE): 689.65
# Mean Absolute Error (MAE): 22.01
# Mean Absolute Percentage Error (MAPE): 0.33%
#
#
# Clark Error Zone Distribution:
# Zone A: 1614.00% (STD: 0.00%)
# Zone B: 894.00% (STD: 0.00%)
# Zone C: 0.00% (STD: 0.00%)
# Zone D: 14.00% (STD: 0.00%)
# Zone E: 0.00% (STD: 0.00%)
#
# === Training patient Subject 2 ===
# Saved predictions for patient Subject 2 at ./glimmer_transformer_results/Subject 2\errors\predictions.csv
# Saved model for patient Subject 2 at ./glimmer_transformer_results/Subject 2\model
#
#
# --------------------- Patient ID: Subject 2 ---------------------
# Overall Error Metrics:
# Root Mean Squared Error (RMSE): 34.37
# Mean Squared Error (MSE): 1181.33
# Mean Absolute Error (MAE): 26.24
# Mean Absolute Percentage Error (MAPE): 0.16%
#
# Normal Region Error Metrics:
# Root Mean Squared Error (RMSE): 22.40
# Mean Squared Error (MSE): 501.87
# Mean Absolute Error (MAE): 17.93
# Mean Absolute Percentage Error (MAPE): 0.13%
#
# dysglycemic Region Error Metrics:
# Root Mean Squared Error (RMSE): 56.68
# Mean Squared Error (MSE): 3212.46
# Mean Absolute Error (MAE): 51.06
# Mean Absolute Percentage Error (MAPE): 0.25%
#
# Hyperglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 56.24
# Mean Squared Error (MSE): 3163.15
# Mean Absolute Error (MAE): 50.67
# Mean Absolute Percentage Error (MAPE): 0.23%
#
# Hypoglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 83.06
# Mean Squared Error (MSE): 6899.10
# Mean Absolute Error (MAE): 79.62
# Mean Absolute Percentage Error (MAPE): 1.24%
#
#
# Clark Error Zone Distribution:
# Zone A: 1607.00% (STD: 0.00%)
# Zone B: 501.00% (STD: 0.00%)
# Zone C: 0.00% (STD: 0.00%)
# Zone D: 8.00% (STD: 0.00%)
# Zone E: 0.00% (STD: 0.00%)
#
# === Training patient Subject 20 ===
# Saved predictions for patient Subject 20 at ./glimmer_transformer_results/Subject 20\errors\predictions.csv
# Saved model for patient Subject 20 at ./glimmer_transformer_results/Subject 20\model
#
#
# --------------------- Patient ID: Subject 20 ---------------------
# Overall Error Metrics:
# Root Mean Squared Error (RMSE): 31.47
# Mean Squared Error (MSE): 990.20
# Mean Absolute Error (MAE): 25.21
# Mean Absolute Percentage Error (MAPE): 0.17%
#
# Normal Region Error Metrics:
# Root Mean Squared Error (RMSE): 25.68
# Mean Squared Error (MSE): 659.21
# Mean Absolute Error (MAE): 21.28
# Mean Absolute Percentage Error (MAPE): 0.16%
#
# dysglycemic Region Error Metrics:
# Root Mean Squared Error (RMSE): 59.31
# Mean Squared Error (MSE): 3517.35
# Mean Absolute Error (MAE): 55.23
# Mean Absolute Percentage Error (MAPE): 0.30%
#
# Hyperglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 61.85
# Mean Squared Error (MSE): 3825.69
# Mean Absolute Error (MAE): 58.76
# Mean Absolute Percentage Error (MAPE): 0.29%
#
# Hypoglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 26.05
# Mean Squared Error (MSE): 678.48
# Mean Absolute Error (MAE): 22.79
# Mean Absolute Percentage Error (MAPE): 0.37%
#
#
# Clark Error Zone Distribution:
# Zone A: 1482.00% (STD: 0.00%)
# Zone B: 1065.00% (STD: 0.00%)
# Zone C: 0.00% (STD: 0.00%)
# Zone D: 9.00% (STD: 0.00%)
# Zone E: 0.00% (STD: 0.00%)
#
# === Training patient Subject 21 ===
# Saved predictions for patient Subject 21 at ./glimmer_transformer_results/Subject 21\errors\predictions.csv
# Saved model for patient Subject 21 at ./glimmer_transformer_results/Subject 21\model
#
#
# --------------------- Patient ID: Subject 21 ---------------------
# Overall Error Metrics:
# Root Mean Squared Error (RMSE): 38.74
# Mean Squared Error (MSE): 1500.72
# Mean Absolute Error (MAE): 29.21
# Mean Absolute Percentage Error (MAPE): 0.18%
#
# Normal Region Error Metrics:
# Root Mean Squared Error (RMSE): 22.62
# Mean Squared Error (MSE): 511.82
# Mean Absolute Error (MAE): 18.08
# Mean Absolute Percentage Error (MAPE): 0.15%
#
# dysglycemic Region Error Metrics:
# Root Mean Squared Error (RMSE): 61.83
# Mean Squared Error (MSE): 3822.80
# Mean Absolute Error (MAE): 55.37
# Mean Absolute Percentage Error (MAPE): 0.26%
#
# Hyperglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 63.13
# Mean Squared Error (MSE): 3986.00
# Mean Absolute Error (MAE): 56.81
# Mean Absolute Percentage Error (MAPE): 0.24%
#
# Hypoglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 39.26
# Mean Squared Error (MSE): 1541.21
# Mean Absolute Error (MAE): 35.21
# Mean Absolute Percentage Error (MAPE): 0.58%
#
#
# Clark Error Zone Distribution:
# Zone A: 1713.00% (STD: 0.00%)
# Zone B: 795.00% (STD: 0.00%)
# Zone C: 0.00% (STD: 0.00%)
# Zone D: 50.00% (STD: 0.00%)
# Zone E: 0.00% (STD: 0.00%)
#
# === Training patient Subject 22 ===
# Saved predictions for patient Subject 22 at ./glimmer_transformer_results/Subject 22\errors\predictions.csv
# Saved model for patient Subject 22 at ./glimmer_transformer_results/Subject 22\model
#
#
# --------------------- Patient ID: Subject 22 ---------------------
# Overall Error Metrics:
# Root Mean Squared Error (RMSE): 36.78
# Mean Squared Error (MSE): 1352.40
# Mean Absolute Error (MAE): 30.09
# Mean Absolute Percentage Error (MAPE): 0.20%
#
# Normal Region Error Metrics:
# Root Mean Squared Error (RMSE): 27.07
# Mean Squared Error (MSE): 732.69
# Mean Absolute Error (MAE): 22.77
# Mean Absolute Percentage Error (MAPE): 0.17%
#
# dysglycemic Region Error Metrics:
# Root Mean Squared Error (RMSE): 59.53
# Mean Squared Error (MSE): 3543.63
# Mean Absolute Error (MAE): 55.99
# Mean Absolute Percentage Error (MAPE): 0.30%
#
# Hyperglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 61.36
# Mean Squared Error (MSE): 3764.83
# Mean Absolute Error (MAE): 58.40
# Mean Absolute Percentage Error (MAPE): 0.28%
#
# Hypoglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 34.75
# Mean Squared Error (MSE): 1207.55
# Mean Absolute Error (MAE): 30.50
# Mean Absolute Percentage Error (MAPE): 0.54%
#
#
# Clark Error Zone Distribution:
# Zone A: 1228.00% (STD: 0.00%)
# Zone B: 891.00% (STD: 0.00%)
# Zone C: 0.00% (STD: 0.00%)
# Zone D: 31.00% (STD: 0.00%)
# Zone E: 0.00% (STD: 0.00%)
#
# === Training patient Subject 23 ===
# Saved predictions for patient Subject 23 at ./glimmer_transformer_results/Subject 23\errors\predictions.csv
# Saved model for patient Subject 23 at ./glimmer_transformer_results/Subject 23\model
#
#
# --------------------- Patient ID: Subject 23 ---------------------
# Overall Error Metrics:
# Root Mean Squared Error (RMSE): 27.75
# Mean Squared Error (MSE): 769.86
# Mean Absolute Error (MAE): 21.18
# Mean Absolute Percentage Error (MAPE): 0.16%
#
# Normal Region Error Metrics:
# Root Mean Squared Error (RMSE): 20.64
# Mean Squared Error (MSE): 425.89
# Mean Absolute Error (MAE): 16.22
# Mean Absolute Percentage Error (MAPE): 0.14%
#
# dysglycemic Region Error Metrics:
# Root Mean Squared Error (RMSE): 46.62
# Mean Squared Error (MSE): 2172.97
# Mean Absolute Error (MAE): 41.43
# Mean Absolute Percentage Error (MAPE): 0.26%
#
# Hyperglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 46.24
# Mean Squared Error (MSE): 2138.48
# Mean Absolute Error (MAE): 40.97
# Mean Absolute Percentage Error (MAPE): 0.19%
#
# Hypoglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 49.36
# Mean Squared Error (MSE): 2436.20
# Mean Absolute Error (MAE): 44.93
# Mean Absolute Percentage Error (MAPE): 0.78%
#
#
# Clark Error Zone Distribution:
# Zone A: 2149.00% (STD: 0.00%)
# Zone B: 446.00% (STD: 0.00%)
# Zone C: 0.00% (STD: 0.00%)
# Zone D: 36.00% (STD: 0.00%)
# Zone E: 0.00% (STD: 0.00%)
#
# === Training patient Subject 24 ===
# Saved predictions for patient Subject 24 at ./glimmer_transformer_results/Subject 24\errors\predictions.csv
# Saved model for patient Subject 24 at ./glimmer_transformer_results/Subject 24\model
#
#
# --------------------- Patient ID: Subject 24 ---------------------
# Overall Error Metrics:
# Root Mean Squared Error (RMSE): 31.16
# Mean Squared Error (MSE): 970.72
# Mean Absolute Error (MAE): 23.82
# Mean Absolute Percentage Error (MAPE): 0.16%
#
# Normal Region Error Metrics:
# Root Mean Squared Error (RMSE): 21.87
# Mean Squared Error (MSE): 478.08
# Mean Absolute Error (MAE): 17.05
# Mean Absolute Percentage Error (MAPE): 0.13%
#
# dysglycemic Region Error Metrics:
# Root Mean Squared Error (RMSE): 54.15
# Mean Squared Error (MSE): 2932.25
# Mean Absolute Error (MAE): 50.77
# Mean Absolute Percentage Error (MAPE): 0.29%
#
# Hyperglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 55.60
# Mean Squared Error (MSE): 3091.78
# Mean Absolute Error (MAE): 52.69
# Mean Absolute Percentage Error (MAPE): 0.26%
#
# Hypoglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 37.95
# Mean Squared Error (MSE): 1440.40
# Mean Absolute Error (MAE): 32.80
# Mean Absolute Percentage Error (MAPE): 0.58%
#
#
# Clark Error Zone Distribution:
# Zone A: 1548.00% (STD: 0.00%)
# Zone B: 336.00% (STD: 0.00%)
# Zone C: 0.00% (STD: 0.00%)
# Zone D: 24.00% (STD: 0.00%)
# Zone E: 0.00% (STD: 0.00%)
#
# === Training patient Subject 25 ===
# Saved predictions for patient Subject 25 at ./glimmer_transformer_results/Subject 25\errors\predictions.csv
# Saved model for patient Subject 25 at ./glimmer_transformer_results/Subject 25\model
#
#
# --------------------- Patient ID: Subject 25 ---------------------
# Overall Error Metrics:
# Root Mean Squared Error (RMSE): 36.23
# Mean Squared Error (MSE): 1312.75
# Mean Absolute Error (MAE): 26.57
# Mean Absolute Percentage Error (MAPE): 0.17%
#
# Normal Region Error Metrics:
# Root Mean Squared Error (RMSE): 22.36
# Mean Squared Error (MSE): 499.91
# Mean Absolute Error (MAE): 17.79
# Mean Absolute Percentage Error (MAPE): 0.15%
#
# dysglycemic Region Error Metrics:
# Root Mean Squared Error (RMSE): 58.59
# Mean Squared Error (MSE): 3432.68
# Mean Absolute Error (MAE): 49.47
# Mean Absolute Percentage Error (MAPE): 0.22%
#
# Hyperglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 59.52
# Mean Squared Error (MSE): 3543.14
# Mean Absolute Error (MAE): 50.26
# Mean Absolute Percentage Error (MAPE): 0.19%
#
# Hypoglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 40.37
# Mean Squared Error (MSE): 1630.12
# Mean Absolute Error (MAE): 36.47
# Mean Absolute Percentage Error (MAPE): 0.59%
#
#
# Clark Error Zone Distribution:
# Zone A: 1653.00% (STD: 0.00%)
# Zone B: 393.00% (STD: 0.00%)
# Zone C: 0.00% (STD: 0.00%)
# Zone D: 16.00% (STD: 0.00%)
# Zone E: 0.00% (STD: 0.00%)
#
# === Training patient Subject 3 ===
# Saved predictions for patient Subject 3 at ./glimmer_transformer_results/Subject 3\errors\predictions.csv
# Saved model for patient Subject 3 at ./glimmer_transformer_results/Subject 3\model
#
#
# --------------------- Patient ID: Subject 3 ---------------------
# Overall Error Metrics:
# Root Mean Squared Error (RMSE): 337.55
# Mean Squared Error (MSE): 113942.81
# Mean Absolute Error (MAE): 81.03
# Mean Absolute Percentage Error (MAPE): 0.82%
#
# Normal Region Error Metrics:
# Root Mean Squared Error (RMSE): 298.11
# Mean Squared Error (MSE): 88868.59
# Mean Absolute Error (MAE): 68.13
# Mean Absolute Percentage Error (MAPE): 0.55%
#
# dysglycemic Region Error Metrics:
# Root Mean Squared Error (RMSE): 523.35
# Mean Squared Error (MSE): 273896.59
# Mean Absolute Error (MAE): 163.30
# Mean Absolute Percentage Error (MAPE): 2.55%
#
# Hyperglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 62.21
# Mean Squared Error (MSE): 3870.60
# Mean Absolute Error (MAE): 60.04
# Mean Absolute Percentage Error (MAPE): 0.29%
#
# Hypoglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 1296.26
# Mean Squared Error (MSE): 1680282.25
# Mean Absolute Error (MAE): 701.12
# Mean Absolute Percentage Error (MAPE): 14.33%
#
#
# Clark Error Zone Distribution:
# Zone A: 840.00% (STD: 0.00%)
# Zone B: 1261.00% (STD: 0.00%)
# Zone C: 64.00% (STD: 0.00%)
# Zone D: 18.00% (STD: 0.00%)
# Zone E: 16.00% (STD: 0.00%)
#
# === Training patient Subject 4 ===
# Saved predictions for patient Subject 4 at ./glimmer_transformer_results/Subject 4\errors\predictions.csv
# Saved model for patient Subject 4 at ./glimmer_transformer_results/Subject 4\model
#
#
# --------------------- Patient ID: Subject 4 ---------------------
# Overall Error Metrics:
# Root Mean Squared Error (RMSE): 40.22
# Mean Squared Error (MSE): 1617.60
# Mean Absolute Error (MAE): 32.17
# Mean Absolute Percentage Error (MAPE): 0.17%
#
# Normal Region Error Metrics:
# Root Mean Squared Error (RMSE): 24.11
# Mean Squared Error (MSE): 581.48
# Mean Absolute Error (MAE): 19.80
# Mean Absolute Percentage Error (MAPE): 0.14%
#
# dysglycemic Region Error Metrics:
# Root Mean Squared Error (RMSE): 59.37
# Mean Squared Error (MSE): 3525.27
# Mean Absolute Error (MAE): 54.94
# Mean Absolute Percentage Error (MAPE): 0.25%
#
# Hyperglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 59.37
# Mean Squared Error (MSE): 3525.27
# Mean Absolute Error (MAE): 54.94
# Mean Absolute Percentage Error (MAPE): 0.25%
#
# Hypoglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): nan
# Mean Squared Error (MSE): nan
# Mean Absolute Error (MAE): nan
# Mean Absolute Percentage Error (MAPE): nan%
#
#
# Clark Error Zone Distribution:
# Zone A: 1196.00% (STD: 0.00%)
# Zone B: 1210.00% (STD: 0.00%)
# Zone C: 0.00% (STD: 0.00%)
# Zone D: 36.00% (STD: 0.00%)
# Zone E: 0.00% (STD: 0.00%)
#
# === Training patient Subject 5 ===
# Saved predictions for patient Subject 5 at ./glimmer_transformer_results/Subject 5\errors\predictions.csv
# Saved model for patient Subject 5 at ./glimmer_transformer_results/Subject 5\model
#
#
# --------------------- Patient ID: Subject 5 ---------------------
# Overall Error Metrics:
# Root Mean Squared Error (RMSE): 32.95
# Mean Squared Error (MSE): 1085.74
# Mean Absolute Error (MAE): 26.76
# Mean Absolute Percentage Error (MAPE): 0.20%
#
# Normal Region Error Metrics:
# Root Mean Squared Error (RMSE): 27.96
# Mean Squared Error (MSE): 781.50
# Mean Absolute Error (MAE): 23.26
# Mean Absolute Percentage Error (MAPE): 0.17%
#
# dysglycemic Region Error Metrics:
# Root Mean Squared Error (RMSE): 50.12
# Mean Squared Error (MSE): 2512.14
# Mean Absolute Error (MAE): 43.14
# Mean Absolute Percentage Error (MAPE): 0.30%
#
# Hyperglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 59.27
# Mean Squared Error (MSE): 3513.21
# Mean Absolute Error (MAE): 56.35
# Mean Absolute Percentage Error (MAPE): 0.28%
#
# Hypoglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 21.33
# Mean Squared Error (MSE): 454.76
# Mean Absolute Error (MAE): 16.00
# Mean Absolute Percentage Error (MAPE): 0.33%
#
#
# Clark Error Zone Distribution:
# Zone A: 1115.00% (STD: 0.00%)
# Zone B: 1387.00% (STD: 0.00%)
# Zone C: 0.00% (STD: 0.00%)
# Zone D: 18.00% (STD: 0.00%)
# Zone E: 0.00% (STD: 0.00%)
#
# === Training patient Subject 6 ===
# Saved predictions for patient Subject 6 at ./glimmer_transformer_results/Subject 6\errors\predictions.csv
# Saved model for patient Subject 6 at ./glimmer_transformer_results/Subject 6\model
#
#
# --------------------- Patient ID: Subject 6 ---------------------
# Overall Error Metrics:
# Root Mean Squared Error (RMSE): 33.92
# Mean Squared Error (MSE): 1150.39
# Mean Absolute Error (MAE): 26.24
# Mean Absolute Percentage Error (MAPE): 0.16%
#
# Normal Region Error Metrics:
# Root Mean Squared Error (RMSE): 24.57
# Mean Squared Error (MSE): 603.82
# Mean Absolute Error (MAE): 19.65
# Mean Absolute Percentage Error (MAPE): 0.14%
#
# dysglycemic Region Error Metrics:
# Root Mean Squared Error (RMSE): 62.59
# Mean Squared Error (MSE): 3916.94
# Mean Absolute Error (MAE): 59.56
# Mean Absolute Percentage Error (MAPE): 0.29%
#
# Hyperglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 62.69
# Mean Squared Error (MSE): 3930.17
# Mean Absolute Error (MAE): 59.68
# Mean Absolute Percentage Error (MAPE): 0.29%
#
# Hypoglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 35.35
# Mean Squared Error (MSE): 1249.29
# Mean Absolute Error (MAE): 34.47
# Mean Absolute Percentage Error (MAPE): 0.52%
#
#
# Clark Error Zone Distribution:
# Zone A: 1285.00% (STD: 0.00%)
# Zone B: 1161.00% (STD: 0.00%)
# Zone C: 0.00% (STD: 0.00%)
# Zone D: 12.00% (STD: 0.00%)
# Zone E: 0.00% (STD: 0.00%)
#
# === Training patient Subject 7 ===
# Saved predictions for patient Subject 7 at ./glimmer_transformer_results/Subject 7\errors\predictions.csv
# Saved model for patient Subject 7 at ./glimmer_transformer_results/Subject 7\model
#
#
# --------------------- Patient ID: Subject 7 ---------------------
# Overall Error Metrics:
# Root Mean Squared Error (RMSE): 34.35
# Mean Squared Error (MSE): 1179.66
# Mean Absolute Error (MAE): 26.33
# Mean Absolute Percentage Error (MAPE): 0.17%
#
# Normal Region Error Metrics:
# Root Mean Squared Error (RMSE): 25.83
# Mean Squared Error (MSE): 667.03
# Mean Absolute Error (MAE): 21.12
# Mean Absolute Percentage Error (MAPE): 0.15%
#
# dysglycemic Region Error Metrics:
# Root Mean Squared Error (RMSE): 69.10
# Mean Squared Error (MSE): 4774.46
# Mean Absolute Error (MAE): 62.84
# Mean Absolute Percentage Error (MAPE): 0.31%
#
# Hyperglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 69.96
# Mean Squared Error (MSE): 4894.21
# Mean Absolute Error (MAE): 63.84
# Mean Absolute Percentage Error (MAPE): 0.30%
#
# Hypoglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 44.22
# Mean Squared Error (MSE): 1955.78
# Mean Absolute Error (MAE): 39.27
# Mean Absolute Percentage Error (MAPE): 0.65%
#
#
# Clark Error Zone Distribution:
# Zone A: 999.00% (STD: 0.00%)
# Zone B: 1531.00% (STD: 0.00%)
# Zone C: 0.00% (STD: 0.00%)
# Zone D: 26.00% (STD: 0.00%)
# Zone E: 0.00% (STD: 0.00%)
#
# === Training patient Subject 8 ===
# Saved predictions for patient Subject 8 at ./glimmer_transformer_results/Subject 8\errors\predictions.csv
# Saved model for patient Subject 8 at ./glimmer_transformer_results/Subject 8\model
#
#
# --------------------- Patient ID: Subject 8 ---------------------
# Overall Error Metrics:
# Root Mean Squared Error (RMSE): 34.14
# Mean Squared Error (MSE): 1165.35
# Mean Absolute Error (MAE): 25.43
# Mean Absolute Percentage Error (MAPE): 0.15%
#
# Normal Region Error Metrics:
# Root Mean Squared Error (RMSE): 19.47
# Mean Squared Error (MSE): 378.96
# Mean Absolute Error (MAE): 15.10
# Mean Absolute Percentage Error (MAPE): 0.12%
#
# dysglycemic Region Error Metrics:
# Root Mean Squared Error (RMSE): 52.22
# Mean Squared Error (MSE): 2727.21
# Mean Absolute Error (MAE): 45.96
# Mean Absolute Percentage Error (MAPE): 0.21%
#
# Hyperglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 52.18
# Mean Squared Error (MSE): 2722.40
# Mean Absolute Error (MAE): 45.91
# Mean Absolute Percentage Error (MAPE): 0.20%
#
# Hypoglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 54.70
# Mean Squared Error (MSE): 2992.05
# Mean Absolute Error (MAE): 48.65
# Mean Absolute Percentage Error (MAPE): 0.77%
#
#
# Clark Error Zone Distribution:
# Zone A: 1211.00% (STD: 0.00%)
# Zone B: 272.00% (STD: 0.00%)
# Zone C: 0.00% (STD: 0.00%)
# Zone D: 22.00% (STD: 0.00%)
# Zone E: 0.00% (STD: 0.00%)
#
# === Training patient Subject 9 ===
# Saved predictions for patient Subject 9 at ./glimmer_transformer_results/Subject 9\errors\predictions.csv
# Saved model for patient Subject 9 at ./glimmer_transformer_results/Subject 9\model
#
#
# --------------------- Patient ID: Subject 9 ---------------------
# Overall Error Metrics:
# Root Mean Squared Error (RMSE): 63.23
# Mean Squared Error (MSE): 3997.95
# Mean Absolute Error (MAE): 54.85
# Mean Absolute Percentage Error (MAPE): 0.26%
#
# Normal Region Error Metrics:
# Root Mean Squared Error (RMSE): 35.28
# Mean Squared Error (MSE): 1244.34
# Mean Absolute Error (MAE): 30.72
# Mean Absolute Percentage Error (MAPE): 0.23%
#
# dysglycemic Region Error Metrics:
# Root Mean Squared Error (RMSE): 78.54
# Mean Squared Error (MSE): 6168.79
# Mean Absolute Error (MAE): 73.88
# Mean Absolute Percentage Error (MAPE): 0.29%
#
# Hyperglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 78.98
# Mean Squared Error (MSE): 6238.22
# Mean Absolute Error (MAE): 74.62
# Mean Absolute Percentage Error (MAPE): 0.29%
#
# Hypoglycemia Region Error Metrics:
# Root Mean Squared Error (RMSE): 14.23
# Mean Squared Error (MSE): 202.61
# Mean Absolute Error (MAE): 10.76
# Mean Absolute Percentage Error (MAPE): 0.16%
#
#
# Clark Error Zone Distribution:
# Zone A: 154.00% (STD: 0.00%)
# Zone B: 1702.00% (STD: 0.00%)
# Zone C: 0.00% (STD: 0.00%)
# Zone D: 165.00% (STD: 0.00%)
# Zone E: 0.00% (STD: 0.00%)
#
# All personalized models trained. Summary saved at ./glimmer_transformer_results/main.csv
# 2026-01-08 10:59:45.020006: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2027] TensorFlow was not built with CUDA kernel binaries compatible with compute capability 12.0. CUDA kernels will be jit-compiled from PTX, which could take 30 minutes or longer.
# 2026-01-08 10:59:45.020213: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-08 10:59:45.021183: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2027] TensorFlow was not built with CUDA kernel binaries compatible with compute capability 12.0. CUDA kernels will be jit-compiled from PTX, which could take 30 minutes or longer.
# 2026-01-08 11:01:26.436559: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13400 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 5060 Ti, pci bus id: 0000:01:00.0, compute capability: 12.0
# 2026-01-08 11:02:34.418637: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# 2026-01-08 11:03:49.390558: E tensorflow/core/platform/windows/subprocess.cc:287] Call to CreateProcess failed. Error code: 2, command: '"ptxas.exe" "--version"'
# 2026-01-08 11:03:49.390791: E tensorflow/core/platform/windows/subprocess.cc:287] Call to CreateProcess failed. Error code: 2, command: '"ptxas.exe" "--version"'
# 2026-01-08 11:03:49.390801: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas.exe --version
# 2026-01-08 11:03:49.392066: E tensorflow/core/platform/windows/subprocess.cc:287] Call to CreateProcess failed. Error code: 2, command: '"ptxas.exe" "C:\Users\MPHIL_~1\AppData\Local\Temp\/tempfile-DESKTOP-PBUCVUG-de8-21384-647da2c25f1da" "-o" "C:\Users\MPHIL_~1\AppData\Local\Temp\/tempfile-DESKTOP-PBUCVUG-de8-21384-647da2c25f5c4" "-arch=sm_120" "--warn-on-spills"'
# 2026-01-08 11:03:49.392207: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2026-01-08 11:05:09.012615: I tensorflow/stream_executor/cuda/cuda_blas.cc:1614] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, query_layer_call_fn, query_layer_call_and_return_conditional_losses while saving (showing 5 of 15). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, query_layer_call_fn, query_layer_call_and_return_conditional_losses while saving (showing 5 of 15). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, query_layer_call_fn, query_layer_call_and_return_conditional_losses while saving (showing 5 of 15). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, query_layer_call_fn, query_layer_call_and_return_conditional_losses while saving (showing 5 of 15). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, query_layer_call_fn, query_layer_call_and_return_conditional_losses while saving (showing 5 of 15). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, query_layer_call_fn, query_layer_call_and_return_conditional_losses while saving (showing 5 of 15). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, query_layer_call_fn, query_layer_call_and_return_conditional_losses while saving (showing 5 of 15). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, query_layer_call_fn, query_layer_call_and_return_conditional_losses while saving (showing 5 of 15). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, query_layer_call_fn, query_layer_call_and_return_conditional_losses while saving (showing 5 of 15). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, query_layer_call_fn, query_layer_call_and_return_conditional_losses while saving (showing 5 of 15). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, query_layer_call_fn, query_layer_call_and_return_conditional_losses while saving (showing 5 of 15). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, query_layer_call_fn, query_layer_call_and_return_conditional_losses while saving (showing 5 of 15). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, query_layer_call_fn, query_layer_call_and_return_conditional_losses while saving (showing 5 of 15). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, query_layer_call_fn, query_layer_call_and_return_conditional_losses while saving (showing 5 of 15). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, query_layer_call_fn, query_layer_call_and_return_conditional_losses while saving (showing 5 of 15). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, query_layer_call_fn, query_layer_call_and_return_conditional_losses while saving (showing 5 of 15). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, query_layer_call_fn, query_layer_call_and_return_conditional_losses while saving (showing 5 of 15). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, query_layer_call_fn, query_layer_call_and_return_conditional_losses while saving (showing 5 of 15). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, query_layer_call_fn, query_layer_call_and_return_conditional_losses while saving (showing 5 of 15). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, query_layer_call_fn, query_layer_call_and_return_conditional_losses while saving (showing 5 of 15). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, query_layer_call_fn, query_layer_call_and_return_conditional_losses while saving (showing 5 of 15). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, query_layer_call_fn, query_layer_call_and_return_conditional_losses while saving (showing 5 of 15). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, query_layer_call_fn, query_layer_call_and_return_conditional_losses while saving (showing 5 of 15). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, query_layer_call_fn, query_layer_call_and_return_conditional_losses while saving (showing 5 of 15). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, query_layer_call_fn, query_layer_call_and_return_conditional_losses while saving (showing 5 of 15). These functions will not be directly callable after loading.

# %% [markdown]
# The summaraize results of personalized models

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# -----------------------------
# Paths
# -----------------------------
out_dir = r"D:\JupyterNotebooks\Azka\Trying to achieve the papers accuracy\GLIMMER Personalzied model\glimmer_transformer_results"
main_csv_path = os.path.join(out_dir, "main.csv")

# -----------------------------
# Load numeric metrics
# -----------------------------
df_metrics = pd.read_csv(main_csv_path)
print(f"Loaded metrics for {len(df_metrics)} patients.")

metrics = ['RMSE_total', 'MAE_total', 'MAPE_total']

numeric_summary = df_metrics[metrics].agg(['mean','median','std'])
print("\nOverall numeric metrics across all patients:\n")
print(numeric_summary)

# -----------------------------
# Aggregate Clarke Error Zones
# -----------------------------
clarke_zones_list = []

for patient_id in df_metrics['PatientID']:
    patient_dir = os.path.join(out_dir, patient_id, "errors")
    clarke_file = os.path.join(patient_dir, "clarke_zones.csv")
    if os.path.exists(clarke_file):
        df_zone = pd.read_csv(clarke_file)
        clarke_zones_list.append(df_zone.iloc[0])  # single row per patient
    else:
        print(f"[WARNING] Clarke file not found for {patient_id}")

# Combine all patient zones
df_clarke = pd.DataFrame(clarke_zones_list)

# Compute mean & std for each zone
clarke_summary = df_clarke.agg(['mean','std'])
print("\nOverall Clarke Error Zones across all patients (% of points in each zone):\n")
print(clarke_summary)

# -----------------------------
# Optional: Boxplot of errors
# -----------------------------
plt.figure(figsize=(10,6))
sns.boxplot(data=df_metrics[metrics])
plt.title("Distribution of Numeric Errors Across Patients")
plt.ylabel("Error Value")
plt.show()

# -----------------------------
# Optional: Bar chart of mean Clarke zones
# -----------------------------
plt.figure(figsize=(8,5))
clarke_summary.loc['mean'].plot(kind='bar', color=['green','yellow','orange','red','purple'])
plt.title("Mean Clarke Error Zone Percentages Across Patients")
plt.ylabel("Percentage of Points (%)")
plt.show()

# -----------------------------
# Save summaries
# -----------------------------
numeric_summary.to_csv(os.path.join(out_dir, "overall_numeric_summary.csv"))
clarke_summary.to_csv(os.path.join(out_dir, "overall_clarke_summary.csv"))
print(f"\nOverall numeric summary saved to {os.path.join(out_dir, 'overall_numeric_summary.csv')}")
print(f"Overall Clarke summary saved to {os.path.join(out_dir, 'overall_clarke_summary.csv')}")
# Out:
# Loaded metrics for 25 patients.
#
# Overall numeric metrics across all patients:
#
#         RMSE_total  MAE_total  MAPE_total
# mean     48.290858  30.652986    0.207194
# median   34.346170  26.357897    0.174717
# std      60.811317  13.009289    0.132082
#
# Overall Clarke Error Zones across all patients (% of points in each zone):
#
#                 A            B      C          D     E
# mean  1282.600000  1012.480000   2.56  33.080000  0.64
# std    527.178654   493.217254  12.80  37.171808  3.20
# Overall numeric summary saved to D:\JupyterNotebooks\Azka\Trying to achieve the papers accuracy\GLIMMER Personalzied model\glimmer_transformer_results\overall_numeric_summary.csv
# Overall Clarke summary saved to D:\JupyterNotebooks\Azka\Trying to achieve the papers accuracy\GLIMMER Personalzied model\glimmer_transformer_results\overall_clarke_summary.csv

# %% [markdown]
# Bars turn red if Clarke A+B < 90% → immediate visual warning.
#
# Green line shows actual Clarke A+B percentage.
#
# Red dashed line marks 90% threshold, the clinical safety target.
#
# Goal: RMSE & MAE low, Clarke A+B ≥ 90%.
#
# Patients falling below 90% are flagged in red for review.

# %%
import plotly.io as pio
pio.renderers.default = "notebook_connected"  # or "notebook" if old version

# %%
import os
import pandas as pd
import plotly.graph_objects as go
import numpy as np

# -----------------------------
# Paths
# -----------------------------
out_dir = "./glimmer_transformer_results"  # folder containing patient folders
main_csv_path = os.path.join(out_dir, "main.csv")

# -----------------------------
# Load numeric metrics
# -----------------------------
df_metrics = pd.read_csv(main_csv_path)
patients = df_metrics['PatientID'].tolist()

# -----------------------------
# Load Clarke zones per patient and compute A+B %
# -----------------------------
clarke_a_b_perc = []

for pid in patients:
    clarke_file = os.path.join(out_dir, pid, "errors", "clarke_zones.csv")
    if os.path.exists(clarke_file):
        df_zone = pd.read_csv(clarke_file)
        total = df_zone[['A','B','C','D','E']].sum(axis=1).values[0]
        a_b_perc = (df_zone['A'].values[0] + df_zone['B'].values[0]) / total * 100
        clarke_a_b_perc.append(a_b_perc)
    else:
        clarke_a_b_perc.append(0)

df_metrics['Clarke_A+B_%'] = clarke_a_b_perc

# -----------------------------
# Prepare figure
# -----------------------------
fig = go.Figure()

# RMSE bars
fig.add_trace(go.Bar(
    x=patients,
    y=df_metrics['RMSE_total'],
    name='RMSE',
    marker_color='salmon',
    yaxis='y1'
))

# MAE bars
fig.add_trace(go.Bar(
    x=patients,
    y=df_metrics['MAE_total'],
    name='MAE',
    marker_color='skyblue',
    yaxis='y1'
))

# Clarke A+B % line
fig.add_trace(go.Scatter(
    x=patients,
    y=df_metrics['Clarke_A+B_%'],
    mode='lines+markers',
    name='Clarke A+B %',
    line=dict(color='green', width=3),
    marker=dict(size=8),
    yaxis='y2'
))

# -----------------------------
# Layout with dual y-axis
# -----------------------------
fig.update_layout(
    title="Personalized Model Results Across Patients",
    xaxis_title="Patient ID",
    yaxis=dict(
        title="Error (mg/dL)",
        side="left",
        showgrid=True,
        zeroline=True,
        range=[0, max(df_metrics[['RMSE_total','MAE_total']].max().max()*1.1, 100)]
    ),
    yaxis2=dict(
        title="% of Points in Clarke A+B",
        overlaying='y',
        side='right',
        range=[0, 100]
    ),
    barmode='group',
    template='plotly_white',
    width=1200,
    height=600
)

# 90% threshold line for Clarke A+B
fig.add_hline(y=90, line_dash="dash", line_color="red", annotation_text="90% Threshold",
              annotation_position="top right", yref='y2')

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="70dbaeff-bf91-4f95-95d6-49dfe5ec1a23" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("70dbaeff-bf91-4f95-95d6-49dfe5ec1a23")) {                    Plotly.newPlot(                        "70dbaeff-bf91-4f95-95d6-49dfe5ec1a23",                        [{"marker":{"color":"salmon"},"name":"RMSE","x":["Subject 1","Subject 10","Subject 11","Subject 12","Subject 13","Subject 14","Subject 15","Subject 16","Subject 17","Subject 18","Subject 19","Subject 2","Subject 20","Subject 21","Subject 22","Subject 23","Subject 24","Subject 25","Subject 3","Subject 4","Subject 5","Subject 6","Subject 7","Subject 8","Subject 9"],"y":{"dtype":"f8","bdata":"ByRiOJ5aQ0C15CDswjY\u002fQCK45FbHoEJAGhQKSIgLQECyxvzGteY5QOcnUixoNkFAZj2VFX+EQEDDon7qcOU\u002fQL6SG4Ika0xAphU0pY5uRUBQATh2RTQ+QJdgDxJuL0FA5x9LEaZ3P0AyeWH2mV5DQNTtib8zY0JAG1ftxhC\u002fO0DcVJDJAyg\u002fQEvJxT6vHUJATz5P2d0YdUDopDk9FBxEQCT9uYqqeUBAkB9QL271QEC5Rh1QTyxBQMAJqt2QEUFAKawctFqdT0A="},"yaxis":"y","type":"bar"},{"marker":{"color":"skyblue"},"name":"MAE","x":["Subject 1","Subject 10","Subject 11","Subject 12","Subject 13","Subject 14","Subject 15","Subject 16","Subject 17","Subject 18","Subject 19","Subject 2","Subject 20","Subject 21","Subject 22","Subject 23","Subject 24","Subject 25","Subject 3","Subject 4","Subject 5","Subject 6","Subject 7","Subject 8","Subject 9"],"y":{"dtype":"f8","bdata":"AAAAgJzZQEAAAABgtF43QAAAAKAe1T1AAAAAIJ9bOkAAAAAgDlQ0QAEAAODViTtAAAAAAGFeNkAAAADgvPY4QAAAAIC6CUhA\u002f\u002f\u002f\u002f\u002f8X4PkAAAADgJK83QAAAACClPDpAAAAAgPI2OUAAAACg6DY9QAAAAOAuFz5AAAAA4FMuNUAAAACgAtE3QAAAAIDTkTpAAAAAAMBBVEAAAACA6RVAQP\u002f\u002f\u002f98awjpAAAAAAII8OkAAAADgp1M6QAAAAOBHbzlAAAAAIGttS0A="},"yaxis":"y","type":"bar"},{"line":{"color":"green","width":3},"marker":{"size":8},"mode":"lines+markers","name":"Clarke A+B %","x":["Subject 1","Subject 10","Subject 11","Subject 12","Subject 13","Subject 14","Subject 15","Subject 16","Subject 17","Subject 18","Subject 19","Subject 2","Subject 20","Subject 21","Subject 22","Subject 23","Subject 24","Subject 25","Subject 3","Subject 4","Subject 5","Subject 6","Subject 7","Subject 8","Subject 9"],"y":{"dtype":"f8","bdata":"S5+NJd35WEDRECT5UrVYQGS3VtcRTVhAb7PeSln9WECsH1BXyvpYQHbDYq5s3lhAkNG3XaKSWEDCxFpPQupYQF\u002f550gI3ldAjDlArCtMWECLJPz+eNxYQEC8y6vN51hAL\u002fVk\u002fHbpWEDN\u002f\u002f765oJYQIk74o64o1hAvFGIwW2oWECJdekxf69YQD0m6udWzlhALoW4icfiV0C9JdyupqFYQCVJkiRJ0lhAW3JHTcHgWED5bpX15b5YQGi5fvdxolhAVlI+hHz1VkA="},"yaxis":"y2","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdc ...

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

out_dir = "./glimmer_transformer_results"  # folder containing patient results

all_preds = []
all_truths = []

# Loop through each patient folder
for pid in os.listdir(out_dir):
    pred_file = os.path.join(out_dir, pid, "errors", "predictions.csv")
    if os.path.exists(pred_file):
        df_pred = pd.read_csv(pred_file)
        all_preds.append(df_pred['y_pred'].values)
        all_truths.append(df_pred['y_true'].values)

# Make sure all arrays are same length
min_len = min([len(p) for p in all_preds])
all_preds = np.array([p[:min_len] for p in all_preds])
all_truths = np.array([t[:min_len] for t in all_truths])

# Compute average
avg_pred = np.mean(all_preds, axis=0)
avg_true = np.mean(all_truths, axis=0)
std_pred = np.std(all_preds, axis=0)

# Plot
plt.figure(figsize=(14,6))
plt.plot(avg_true, label="Average True Glucose", color="blue")
plt.plot(avg_pred, label="Average Predicted Glucose", color="orange")
plt.fill_between(range(len(avg_pred)),
                 avg_pred - std_pred,
                 avg_pred + std_pred,
                 color='orange', alpha=0.3, label="±1 STD")
plt.xlabel("Time Index")
plt.ylabel("Glucose (mg/dL)")
plt.title("Average Glucose Prediction Across All Patients")
plt.legend()
plt.show()
